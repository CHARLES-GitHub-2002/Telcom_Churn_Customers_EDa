# %% [markdown]
# ### CHURN ANALYSIS - EDA
# _**Dataset info : sample dataset containing customer data and showing customers who left last month**_

# %%
# importing the required  libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import matplotlib.ticker as mtick  
# %matplotlib inline

# %% [markdown]
# _**loading the dataset**_

# %%
df=pd.read_csv(r"C:\Users\MUNYUA CHARLES\Downloads\CustomerChurn.csv")

# %% [markdown]
# _**looking at the 5 top most rows**_

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# _**Looking at the bootom 5 rows**_

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# _**Cheaking for colunms,rows and datatypes**_

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
# Cheaking for the data types of the columns 
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#Cheaking for Descriptive statistics of numerical values 
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['Churn'].value_counts()/len(df)*100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: count, dtype: float64

# %%
df['Churn'].value_counts().plot(kind='barh',figsize=(6,4))
plt.xlabel('COUNT',labelpad=14 )
plt.ylabel('Target Variable',labelpad=14)
plt.title('Count of Target Variable Per Category',y=1.02)
plt.show()

# %%
# Consise summary of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
missing = pd.DataFrame((df.isnull().sum()) * 100 / df.shape[0]).reset_index()
missing.columns = ['index', 'percentage']  # Rename columns for clarity

plt.figure(figsize=(6, 4))
ax = sns.pointplot(x='index', y='percentage', data=missing)
plt.xticks(rotation=90, fontsize=7)
plt.title("Percentage of Missing Values")
plt.ylabel("Percentage")  # Fixed the typo from 'ylables' to 'ylabel'
plt.show()

# %% [markdown]
# ### Missing values in the dataframe
# we do not have missing value in the dataset
# # General Thumps Rules
# - For fetures with less missing values, regression can be used to predict the missing values or fill the missing values with the mean of the values present,depending on the features.
# - For features with very high number of missing values, it is better to drop the columns as they give very less insight on the analysis.
# -

# %% [markdown]
# ### Data Cleaning
# 1. Creating a copy of the dataframe for manipulation and processing.

# %%
New_df=df.copy()

# %% [markdown]
# 2. TotalCharges should be numerical ammount we convert it to numerical data type

# %%
New_df.TotalCharges=pd.to_numeric(New_df.TotalCharges,errors="coerce")
New_df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# 3. we have 11 missing values in the Totalcharges colunms

# %%
New_df.loc[New_df['TotalCharges'].isnull()== True]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# # Missing Values Treatment
# since the % of this missing values in very low less than 1%. It is safe to ignore them in futher processing.

# %%
#Removing the missing values 
New_df.dropna(how='any', inplace=True )

# %% [markdown]
# 5. Dividing customers into bins based on tenure e.g for tenure< 12 months assign a tenure group of 1-12,for tenure between 1 to 2 years ,tenure group of 13-24 and so on

# %% [markdown]
# #getting the max Tenure
# print(New_df['tenure'].max())

# %%
labels = ['{0}-{1}'.format(i,i+11)for i in range (1,72,12)]
print(labels)
# Out:
# ['1-12', '13-24', '25-36', '37-48', '49-60', '61-72']

# %%
#Group the tenure in bins of 12 months
New_df['tenure_group']=pd.cut(New_df.tenure, range(1,80,12),right=False,labels=labels)
New_df['tenure_group'].value_counts()
# Out:
# tenure_group
# 1-12     2175
# 61-72    1407
# 13-24    1024
# 25-36     832
# 49-60     832
# 37-48     762
# Name: count, dtype: int64

# %% [markdown]
# 6. Removing the columns that are not needed in the processing

# %%
New_df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'tenure_group'],
#       dtype='object')

# %%
#Droping tenure and customerID columns 
New_df.drop(columns=['tenure','customerID'] ,axis=1,inplace=True)

# %%
New_df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# ## Univariate Analysis
# 1. Plot distribution of individual predictor by churn

# %%
New_df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %%
for i, predictor in enumerate(New_df.drop(columns=['Churn', 'TotalCharges', 'MonthlyCharges']).columns):
    plt.figure(i)
    sns.countplot(data=New_df, x=predictor, hue="Churn")
    plt.title(f"Countplot for {predictor} by Churn")
    plt.show()

# %% [markdown]
# ### Insignts of Univariate Analysis

# %% [markdown]
# 2. Convertion of churn variable into a binary numeric variable yes=1,no=0

# %%
# Clean the column for consistent formatting
New_df['Churn'] = New_df['Churn'].astype(str).str.strip().str.lower()
# Replace 'yes' with 1 and 'no' with 0
new_df = New_df.replace({'Churn': {'yes': 1, 'no': 0}})
# Explicitly downcast (optional if you rely on old behavior)
new_df = new_df.infer_objects(copy=False)
# Check the first few rows
new_df.head()
# Out:
# C:\Users\MUNYUA CHARLES\AppData\Local\Temp\ipykernel_6132\2722341823.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   new_df = New_df.replace({'Churn': {'yes': 1, 'no': 0}})
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# ...

# %% [markdown]
# 3. Converting Categolical Variable In to dummy variables
# - *Dummy variables (also called indicator variables) are binary variables used to represent categorical data in a form that can be easily understood by machine learning algorithms or statistical models.*

# %%
# Create dummy variables
df_dummies = pd.get_dummies(new_df)
# Convert all columns in df_dummies to integers (1 and 0)
df_dummies = df_dummies.astype(int)
df_dummies.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0              29            29      0              1
# 1              0              56          1889      0              0
# 2              0              53           108      1              0
# 3              0              42          1840      0              0
# 4              0              70           151      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
# ...

# %% [markdown]
# 4. Relationship Between Monthly Charges and Total Charges

# %%
sns.scatterplot(data=df_dummies, x='MonthlyCharges', y='TotalCharges')
# Add title and labels
plt.title("Monthly Charges vs. Total Charges")
plt.xlabel("Monthly Charges")
plt.ylabel("Total Charges")
# Show plot
plt.show()

# %% [markdown]
# Total charges increse as monthly charges increse - as expected

# %% [markdown]
# 5. Build a correration of all predictors with Churn

# %%
# Plot
# Calculate the correlation matrix and extract correlations with 'Churn'
correlations = df_dummies.corr()['Churn'].sort_values(ascending=False)
# Plot the correlations
plt.figure(figsize=(20, 8))
correlations.plot(kind='bar', color='blue', edgecolor='black')# Add title and labels
plt.title("Feature Correlation with Churn", fontsize=16)
plt.ylabel("Correlation Coefficient", fontsize=12)
plt.xlabel("Features", fontsize=20)
# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Derived Insight:**
#
# - HIGH Churn seen in case of Month to month contracts, No online security, No Tech support, First year of subscription and Fibre Optics Internet
#
# - LOW Churn is seens in case of Long term contracts, Subscriptions without internet service and The customers engaged for 5+ years
#
# - Factors like Gender, Availability of PhoneService and # of multiple lines have alomost NO impact on Churn
#
# This is also evident from the Heatmap below

# %%
# Plot the heatmap

plt.figure(figsize=(12,12))
sns.heatmap(df_dummies.corr(), cmap="Paired")
# Add title for the heatmap
plt.title("Correlation Matrix Heatmap", fontsize=16)
# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
new_df1_target0=new_df.loc[new_df["Churn"]==0]
new_df1_target1=new_df.loc[new_df["Churn"]==1]

# %%
def uniplot(df,col,title,hue =None):
    
    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"] = 20
    plt.rcParams['axes.titlesize'] = 22
    plt.rcParams['axes.titlepad'] = 30
    
    
    temp = pd.Series(data = hue)
    fig, ax = plt.subplots()
    width = len(df[col].unique()) + 7 + 4*len(temp.unique())
    fig.set_size_inches(width , 8)
    plt.xticks(rotation=45)
    plt.yscale('log')
    plt.title(title)
    ax = sns.countplot(data = new_df, x= col, order=new_df[col].value_counts().index,hue = hue,palette='bright') 
        
    plt.show()

# %%
uniplot(new_df1_target1,col='Partner',title='Distribution of Gender for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target0,col='Partner',title='Distribution of Gender for Non Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='PaymentMethod',title='Distribution of PaymentMethod for Churned Customers',hue='gender')
